# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dir_results = "../../patch_padding/"

# %%
df_resnet_18 = pd.read_csv(os.path.join(dir_results, "resnet_18_deeplab_v3+/train_metrics.csv"))
df_resnet_34 = pd.read_csv(os.path.join(dir_results, "resnet_34_deeplab_v3+/train_metrics.csv"))
df_resnet_50 = pd.read_csv(os.path.join(dir_results, "resnet_50_deeplab_v3+/train_metrics.csv"))
df_resnet_101 = pd.read_csv(os.path.join(dir_results, "resnet_101_deeplab_v3+/train_metrics.csv"))

# %%
df_effnet_v2_s = pd.read_csv(os.path.join(dir_results, "efficientnet_v2_s_deeplab_v3/train_metrics.csv"))
df_effnet_v2_m = pd.read_csv(os.path.join(dir_results, "efficientnet_v2_m_deeplab_v3/train_metrics.csv"))

# %% [markdown]
# ## ResNet18 - DeepLab_v3+

# %%
df_resnet_18.head()
# Out:
#    epoch  train_loss  valid_loss  valid_acc  valid_IOU
# 0      1     0.49314     0.30538    0.89931    0.27656
# 1      2     0.32972     0.30436    0.89839    0.26528
# 2      3     0.30557     0.23259    0.92010    0.30900
# 3      4     0.28305     0.23261    0.91452    0.31416
# 4      5     0.28002     0.24485    0.90370    0.30822

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_resnet_18.shape[0]+1), df_resnet_18.train_loss, label="train loss")
plt.plot(np.arange(1, df_resnet_18.shape[0]+1), df_resnet_18.valid_loss, label="validation loss")
plt.title("train/validation loss vs epoch for resnet18 - deeplab_v3+ model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("loss", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/3121007610.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_resnet_18.shape[0]+1), df_resnet_18.valid_acc, label="validation accuracy")
plt.title("validation accuracy vs epoch for resnet18 - deeplab_v3+ model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("accuracy score", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/3267226786.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## ResNet34 - DeepLab_v3+

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_resnet_34.shape[0]+1), df_resnet_34.train_loss, label="train loss")
plt.plot(np.arange(1, df_resnet_34.shape[0]+1), df_resnet_34.valid_loss, label="validation loss")
plt.title("train/validation loss vs epoch for resnet34 - deeplab_v3+ model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("loss", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/2995400262.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_resnet_34.shape[0]+1), df_resnet_34.valid_acc, label="validation accuracy")
plt.title("validation accuracy vs epoch for resnet34 - deeplab_v3+ model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("accuracy score", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/1297644331.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## ResNet50 - DeepLab_v3+

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_resnet_50.shape[0]+1), df_resnet_50.train_loss, label="train loss")
plt.plot(np.arange(1, df_resnet_50.shape[0]+1), df_resnet_50.valid_loss, label="validation loss")
plt.title("train/validation loss vs epoch for resnet50 - deeplab_v3+ model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("loss", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/988750659.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_resnet_50.shape[0]+1), df_resnet_50.valid_acc, label="validation accuracy")
plt.title("validation accuracy vs epoch for resnet50 - deeplab_v3+ model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("accuracy score", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/4258916153.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## ResNet101 - DeepLab_v3+

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_resnet_101.shape[0]+1), df_resnet_101.train_loss, label="train loss")
plt.plot(np.arange(1, df_resnet_101.shape[0]+1), df_resnet_101.valid_loss, label="validation loss")
plt.title("train/validation loss vs epoch for resnet101 - deeplab_v3+ model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("loss", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/893669075.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_resnet_101.shape[0]+1), df_resnet_101.valid_acc, label="validation accuracy")
plt.title("validation accuracy vs epoch for resnet101 - deeplab_v3+ model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("accuracy score", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/2862281149.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## EfficientNet_v2_s - DeepLab_v3

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_effnet_v2_s.shape[0]+1), df_effnet_v2_s.train_loss, label="train loss")
plt.plot(np.arange(1, df_effnet_v2_s.shape[0]+1), df_effnet_v2_s.valid_loss, label="validation loss")
plt.title("train/validation loss vs epoch for efficientnet_v2_s - deeplab_v3 model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("loss", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/1678374897.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_effnet_v2_s.shape[0]+1), df_effnet_v2_s.valid_acc, label="validation accuracy")
plt.title("validation accuracy vs epoch for efficientnet_v2_s - deeplab_v3 model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("accuracy score", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/356537624.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## EfficientNet_v2_m - DeepLab_v3

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_effnet_v2_m.shape[0]+1), df_effnet_v2_m.train_loss, label="train loss")
plt.plot(np.arange(1, df_effnet_v2_m.shape[0]+1), df_effnet_v2_m.valid_loss, label="validation loss")
plt.title("train/validation loss vs epoch for efficientnet_v2_m - deeplab_v3 model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("loss", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/2942016443.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure(figsize=(12, 8))
plt.plot(np.arange(1, df_effnet_v2_m.shape[0]+1), df_effnet_v2_m.valid_acc, label="validation accuracy")
plt.title("validation accuracy vs epoch for efficientnet_v2_m - deeplab_v3 model", fontsize=20)
plt.xlabel("epoch", fontsize=20)
plt.ylabel("accuracy score", fontsize=20)
plt.legend(fontsize=20)
plt.grid()
fig.show()
# Out:
# /tmp/ipykernel_56688/3731405208.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
